# %%
import os
import random

import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import torch
import torchvision

from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import datasets, transforms

from helper_evaluation import set_all_seeds, compute_confusion_matrix
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helper_dataset import UnNormalize

# %%
torch.cuda.empty_cache()
random_seed = 42
train_root = 'train_images'
NUM_EPOCHS = 40
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

set_all_seeds(random_seed)

# %%
train_table = pd.read_csv('train.csv')
train_table.head()
# Out:
#          image_id  label
# 0  1000015157.jpg      0
# 1  1000201771.jpg      3
# 2   100042118.jpg      1
# 3  1000723321.jpg      1
# 4  1000812911.jpg      3

# %%
train_table.shape
# Out:
# (21397, 2)

# %%
train_table['label'].value_counts()
# Out:
# 3    13158
# 4     2577
# 2     2386
# 1     2189
# 0     1087
# Name: label, dtype: int64

# %%
train_paths = [os.path.join(train_root, file) for file in train_table['image_id']]
train_labels = train_table['label'].values

# %%
# sizes = set()
# modes = set()
# for path in train_paths:
#     pic = Image.open(path)
#     sizes.add(pic.size)
#     modes.add(pic.mode)
# print(sizes)
# print(modes)

# %%
normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225]
)
preprocess = transforms.Compose([
    #transforms.Scale(256),
    #transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize
])

def default_loader(path):
    img_pil =  Image.open(path)
    img_pil = img_pil.resize((400,300))
    img_tensor = preprocess(img_pil)
    return img_tensor

# %%
# class MyDataset(Dataset):
#     def __init__(self, img_paths, labels, loader=default_loader):
#         self.img_paths = img_paths
#         self.labels = labels
#         self.loader = loader
        
#     def __getitem__(self, index):
#         img_path, label = self.img_paths[index], self.labels[index]
#         img = self.loader(img_path)
        
#         return img, label
    
#     def __len__(self):
#         return len(self.labels)

# %%
class MyDataset(Dataset):
    def __init__(self, img_paths, labels, loader=default_loader):
        self.imgs = [loader(path) for path in img_paths]
        self.labels = labels
        
    def __getitem__(self, index):
        return self.imgs[index], self.labels[index]
    
    def __len__(self):
        return len(self.labels)

# %%
dataset = MyDataset(train_paths, train_labels)
len(dataset)*np.array([0.8,0.05,0.15])
# Out:
# array([17117.6 ,  1069.85,  3209.55])

# %%
train_dataset, val_dataset, test_dataset = random_split(dataset, [17118 ,  1070,  3209], generator=torch.Generator().manual_seed(random_seed))

# %%
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
model = torchvision.models.squeezenet1_0(pretrained=True)
model = model.to(device)

# %%
optimizer = torch.optim.SGD(model.parameters(), momentum=0.7, lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                            step_size=10,
                                            gamma=0.5,
                                           last_epoch=-1)

# %%
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=device,
    scheduler=scheduler,
    scheduler_on='epoch',
    logging_interval=100)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=200)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([60, 100])
plt.show()
# Out:
# Learning rate: [0.001]
# Epoch: 001/040 | Batch 0000/0268 | Loss: 10.4523
# Epoch: 001/040 | Batch 0100/0268 | Loss: 1.0347
# Epoch: 001/040 | Batch 0200/0268 | Loss: 0.7288
# Epoch: 001/040 | Train: 70.66% | Validation: 72.80%
# Time elapsed: 1.87 min
# Learning rate: [0.001]
# Epoch: 002/040 | Batch 0000/0268 | Loss: 0.6746
# Epoch: 002/040 | Batch 0100/0268 | Loss: 0.6680
# Epoch: 002/040 | Batch 0200/0268 | Loss: 0.8017
# Epoch: 002/040 | Train: 75.14% | Validation: 77.76%
# Time elapsed: 3.53 min
# Learning rate: [0.001]
# Epoch: 003/040 | Batch 0000/0268 | Loss: 0.7434
# Epoch: 003/040 | Batch 0100/0268 | Loss: 0.5069
# Epoch: 003/040 | Batch 0200/0268 | Loss: 0.5724
# Epoch: 003/040 | Train: 77.60% | Validation: 79.81%
# Time elapsed: 5.24 min
# Learning rate: [0.001]
# Epoch: 004/040 | Batch 0000/0268 | Loss: 0.6178
# Epoch: 004/040 | Batch 0100/0268 | Loss: 0.7553
# Epoch: 004/040 | Batch 0200/0268 | Loss: 0.7166
# Epoch: 004/040 | Train: 78.54% | Validation: 80.56%
# Time elapsed: 6.91 min
# Learning rate: [0.001]
# Epoch: 005/040 | Batch 0000/0268 | Loss: 0.5587
# Epoch: 005/040 | Batch 0100/0268 | Loss: 0.5564
# Epoch: 005/040 | Batch 0200/0268 | Loss: 0.5985
# Epoch: 005/040 | Train: 79.97% | Validation: 82.99%
# Time elapsed: 8.57 min
# Learning rate: [0.001]
# Epoch: 006/040 | Batch 0000/0268 | Loss: 0.4109
# Epoch: 006/040 | Batch 0100/0268 | Loss: 0.5038
# Epoch: 006/040 | Batch 0200/0268 | Loss: 0.4942
# Epoch: 006/040 | Train: 82.84% | Validation: 84.49%
# Time elapsed: 10.24 min
# Learning rate: [0.001]
# Epoch: 007/040 | Batch 0000/0268 | Loss: 0.3946
# Epoch: 007/040 | Batch 0100/0268 | Loss: 0.4611
# Epoch: 007/040 | Batch 0200/0268 | Loss: 0.6825
# Epoch: 007/040 | Train: 81.91% | Validation: 84.11%
# Time elapsed: 11.90 min
# Learning rate: [0.001]
# Epoch: 008/040 | Batch 0000/0268 | Loss: 0.5383
# Epoch: 008/040 | Batch 0100/0268 | Loss: 0.5501
# Epoch: 008/040 | Batch 0200/0268 | Loss: 0.5205
# Epoch: 008/040 | Train: 83.75% | Validation: 83.93%
# Time elapsed: 13.56 min
# Learning rate: [0.001]
# Epoch: 009/040 | Batch 0000/0268 | Loss: 0.4760
# Epoch: 009/040 | Batch 0100/0268 | Loss: 0.4837
# Epoch: 009/040 | Batch 0200/0268 | Loss: 0.6360
# Epoch: 009/040 | Train: 84.56% | Validation: 85.61%
# Time elapsed: 15.22 min
# Learning rate: [0.001]
# Epoch: 010/040 | Batch 0000/0268 | Loss: 0.3705
# Epoch: 010/040 | Batch 0100/0268 | Loss: 0.3519
# Epoch: 010/040 | Batch 0200/0268 | Loss: 0.3316
# Epoch: 010/040 | Train: 85.22% | Validation: 85.98%
# Time elapsed: 16.89 min
# Learning rate: [0.0005]
# Epoch: 011/040 | Batch 0000/0268 | Loss: 0.3787
# Epoch: 011/040 | Batch 0100/0268 | Loss: 0.4934
# Epoch: 011/040 | Batch 0200/0268 | Loss: 0.3768
# Epoch: 011/040 | Train: 85.72% | Validation: 86.45%
# Time elapsed: 18.55 min
# Learning rate: [0.0005]
# Epoch: 012/040 | Batch 0000/0268 | Loss: 0.5561
# Epoch: 012/040 | Batch 0100/0268 | Loss: 0.2641
# Epoch: 012/040 | Batch 0200/0268 | Loss: 0.3066
# Epoch: 012/040 | Train: 84.76% | Validation: 84.58%
# Time elapsed: 20.21 min
# Learning rate: [0.0005]
# Epoch: 013/040 | Batch 0000/0268 | Loss: 0.4349
# Epoch: 013/040 | Batch 0100/0268 | Loss: 0.2539
# Epoch: 013/040 | Batch 0200/0268 | Loss: 0.4211
# Epoch: 013/040 | Train: 86.23% | Validation: 86.82%
# Time elapsed: 21.87 min
# Learning rate: [0.0005]
# Epoch: 014/040 | Batch 0000/0268 | Loss: 0.5832
# Epoch: 014/040 | Batch 0100/0268 | Loss: 0.5955
# Epoch: 014/040 | Batch 0200/0268 | Loss: 0.2134
# Epoch: 014/040 | Train: 85.42% | Validation: 86.82%
# Time elapsed: 23.53 min
# Learning rate: [0.0005]
# Epoch: 015/040 | Batch 0000/0268 | Loss: 0.3699
# Epoch: 015/040 | Batch 0100/0268 | Loss: 0.4220
# Epoch: 015/040 | Batch 0200/0268 | Loss: 0.4606
# Epoch: 015/040 | Train: 86.13% | Validation: 86.36%
# Time elapsed: 25.19 min
# Learning rate: [0.0005]
# Epoch: 016/040 | Batch 0000/0268 | Loss: 0.3512
# Epoch: 016/040 | Batch 0100/0268 | Loss: 0.2505
# Epoch: 016/040 | Batch 0200/0268 | Loss: 0.4297
# Epoch: 016/040 | Train: 86.74% | Validation: 86.26%
# Time elapsed: 26.84 min
# Learning rate: [0.0005]
# Epoch: 017/040 | Batch 0000/0268 | Loss: 0.3989
# Epoch: 017/040 | Batch 0100/0268 | Loss: 0.3339
# Epoch: 017/040 | Batch 0200/0268 | Loss: 0.4409
# Epoch: 017/040 | Train: 86.15% | Validation: 85.89%
# Time elapsed: 28.50 min
# Learning rate: [0.0005]
# Epoch: 018/040 | Batch 0000/0268 | Loss: 0.3952
# Epoch: 018/040 | Batch 0100/0268 | Loss: 0.4341
# Epoch: 018/040 | Batch 0200/0268 | Loss: 0.3412
# Epoch: 018/040 | Train: 86.53% | Validation: 86.64%
# Time elapsed: 30.16 min
# Learning rate: [0.0005]
# Epoch: 019/040 | Batch 0000/0268 | Loss: 0.3327
# Epoch: 019/040 | Batch 0100/0268 | Loss: 0.3309
# Epoch: 019/040 | Batch 0200/0268 | Loss: 0.5461
# Epoch: 019/040 | Train: 86.56% | Validation: 87.38%
# Time elapsed: 31.82 min
# Learning rate: [0.0005]
# Epoch: 020/040 | Batch 0000/0268 | Loss: 0.4744
# Epoch: 020/040 | Batch 0100/0268 | Loss: 0.3934
# Epoch: 020/040 | Batch 0200/0268 | Loss: 0.3709
# Epoch: 020/040 | Train: 86.79% | Validation: 86.73%
# Time elapsed: 33.49 min
# Learning rate: [0.00025]
# Epoch: 021/040 | Batch 0000/0268 | Loss: 0.3685
# Epoch: 021/040 | Batch 0100/0268 | Loss: 0.3518
# Epoch: 021/040 | Batch 0200/0268 | Loss: 0.4111
# Epoch: 021/040 | Train: 87.26% | Validation: 86.45%
# Time elapsed: 35.16 min
# Learning rate: [0.00025]
# Epoch: 022/040 | Batch 0000/0268 | Loss: 0.4824
# Epoch: 022/040 | Batch 0100/0268 | Loss: 0.4689
# Epoch: 022/040 | Batch 0200/0268 | Loss: 0.3405
# Epoch: 022/040 | Train: 87.10% | Validation: 85.89%
# Time elapsed: 36.82 min
# Learning rate: [0.00025]
# Epoch: 023/040 | Batch 0000/0268 | Loss: 0.5423
# Epoch: 023/040 | Batch 0100/0268 | Loss: 0.2575
# Epoch: 023/040 | Batch 0200/0268 | Loss: 0.3886
# Epoch: 023/040 | Train: 87.27% | Validation: 86.17%
# Time elapsed: 38.48 min
# Learning rate: [0.00025]
# Epoch: 024/040 | Batch 0000/0268 | Loss: 0.3776
# Epoch: 024/040 | Batch 0100/0268 | Loss: 0.4509
# Epoch: 024/040 | Batch 0200/0268 | Loss: 0.4094
# Epoch: 024/040 | Train: 87.42% | Validation: 85.33%
# Time elapsed: 40.15 min
# Learning rate: [0.00025]
# Epoch: 025/040 | Batch 0000/0268 | Loss: 0.3593
# Epoch: 025/040 | Batch 0100/0268 | Loss: 0.3337
# Epoch: 025/040 | Batch 0200/0268 | Loss: 0.5591
# Epoch: 025/040 | Train: 87.59% | Validation: 86.17%
# Time elapsed: 41.81 min
# Early stopping
# Total Training Time: 41.81 min
# Test accuracy 85.01%

# %%
model.cpu()
unnormalizer = UnNormalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
class_dict = {0: 'CBB',
              1: 'CBSD',
              2: 'CGM',
              3: 'CMD',
              4: 'Healthy'}

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %%
mat = compute_confusion_matrix(model=model, data_loader=test_loader, device=torch.device('cpu'))
plot_confusion_matrix(mat, class_names=class_dict.values())
plt.show()

# %%
torch.save(model.state_dict(), 'squeezenet1_0.mdl')
