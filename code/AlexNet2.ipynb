# %%
import os
import random

import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import torch
import torchvision

from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import datasets, transforms

from helper_evaluation import set_all_seeds, compute_confusion_matrix
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helper_dataset import UnNormalize

# %%
torch.cuda.empty_cache()
random_seed = 42
train_root = 'train_images'
NUM_EPOCHS = 40
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

set_all_seeds(random_seed)

# %%
train_table = pd.read_csv('train.csv')
train_table.head()
# Out:
#          image_id  label
# 0  1000015157.jpg      0
# 1  1000201771.jpg      3
# 2   100042118.jpg      1
# 3  1000723321.jpg      1
# 4  1000812911.jpg      3

# %%
train_table.shape
# Out:
# (21397, 2)

# %%
train_table['label'].value_counts()
# Out:
# 3    13158
# 4     2577
# 2     2386
# 1     2189
# 0     1087
# Name: label, dtype: int64

# %%
train_paths = [os.path.join(train_root, file) for file in train_table['image_id']]
train_labels = train_table['label'].values

# %%
# sizes = set()
# modes = set()
# for path in train_paths:
#     pic = Image.open(path)
#     sizes.add(pic.size)
#     modes.add(pic.mode)
# print(sizes)
# print(modes)

# %%
normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225]
)
preprocess = transforms.Compose([
    #transforms.Scale(256),
    #transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize
])

def default_loader(path):
    img_pil =  Image.open(path)
    img_pil = img_pil.resize((400,300))
    img_tensor = preprocess(img_pil)
    return img_tensor

# %%
class MyDataset(Dataset):
    def __init__(self, img_paths, labels, loader=default_loader):
        self.img_paths = img_paths
        self.labels = labels
        self.loader = loader
        
    def __getitem__(self, index):
        img_path, label = self.img_paths[index], self.labels[index]
        img = self.loader(img_path)
        
        return img, label
    
    def __len__(self):
        return len(self.labels)

# %%
dataset = MyDataset(train_paths, train_labels)
len(dataset)*np.array([0.8,0.05,0.15])
# Out:
# array([17117.6 ,  1069.85,  3209.55])

# %%
train_dataset, val_dataset, test_dataset = random_split(dataset, [17118 ,  1070,  3209], generator=torch.Generator().manual_seed(random_seed))

# %%
batch_size = 128
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
model = torchvision.models.alexnet(pretrained=True)
model = model.to(device)

# %%
optimizer = torch.optim.SGD(model.parameters(), momentum=0.7, lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                            step_size=10,
                                            gamma=0.5,
                                           last_epoch=-1)

# %%
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=device,
    scheduler=scheduler,
    scheduler_on='epoch',
    logging_interval=100)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=200)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([60, 100])
plt.show()
# Out:
# Learning rate: [0.001]
# Epoch: 001/040 | Batch 0000/0134 | Loss: 12.2503
# Epoch: 001/040 | Batch 0100/0134 | Loss: 0.8886
# Epoch: 001/040 | Train: 69.35% | Validation: 71.96%
# Time elapsed: 2.75 min
# Learning rate: [0.001]
# Epoch: 002/040 | Batch 0000/0134 | Loss: 0.8592
# Epoch: 002/040 | Batch 0100/0134 | Loss: 0.8903
# Epoch: 002/040 | Train: 72.20% | Validation: 73.18%
# Time elapsed: 5.50 min
# Learning rate: [0.001]
# Epoch: 003/040 | Batch 0000/0134 | Loss: 0.8048
# Epoch: 003/040 | Batch 0100/0134 | Loss: 0.9423
# Epoch: 003/040 | Train: 73.76% | Validation: 75.89%
# Time elapsed: 8.23 min
# Learning rate: [0.001]
# Epoch: 004/040 | Batch 0000/0134 | Loss: 0.7665
# Epoch: 004/040 | Batch 0100/0134 | Loss: 0.5974
# Epoch: 004/040 | Train: 74.95% | Validation: 76.36%
# Time elapsed: 10.96 min
# Learning rate: [0.001]
# Epoch: 005/040 | Batch 0000/0134 | Loss: 0.7215
# Epoch: 005/040 | Batch 0100/0134 | Loss: 0.8006
# Epoch: 005/040 | Train: 75.87% | Validation: 77.48%
# Time elapsed: 13.67 min
# Learning rate: [0.001]
# Epoch: 006/040 | Batch 0000/0134 | Loss: 0.5837
# Epoch: 006/040 | Batch 0100/0134 | Loss: 0.6995
# Epoch: 006/040 | Train: 76.43% | Validation: 77.57%
# Time elapsed: 16.38 min
# Learning rate: [0.001]
# Epoch: 007/040 | Batch 0000/0134 | Loss: 0.7977
# Epoch: 007/040 | Batch 0100/0134 | Loss: 0.6737
# Epoch: 007/040 | Train: 77.89% | Validation: 78.41%
# Time elapsed: 19.10 min
# Learning rate: [0.001]
# Epoch: 008/040 | Batch 0000/0134 | Loss: 0.7089
# Epoch: 008/040 | Batch 0100/0134 | Loss: 0.6452
# Epoch: 008/040 | Train: 77.80% | Validation: 78.60%
# Time elapsed: 21.81 min
# Learning rate: [0.001]
# Epoch: 009/040 | Batch 0000/0134 | Loss: 0.5902
# Epoch: 009/040 | Batch 0100/0134 | Loss: 0.6543
# Epoch: 009/040 | Train: 78.71% | Validation: 78.88%
# Time elapsed: 24.52 min
# Learning rate: [0.001]
# Epoch: 010/040 | Batch 0000/0134 | Loss: 0.6664
# Epoch: 010/040 | Batch 0100/0134 | Loss: 0.6584
# Epoch: 010/040 | Train: 79.54% | Validation: 79.72%
# Time elapsed: 27.24 min
# Learning rate: [0.0005]
# Epoch: 011/040 | Batch 0000/0134 | Loss: 0.4898
# Epoch: 011/040 | Batch 0100/0134 | Loss: 0.5896
# Epoch: 011/040 | Train: 79.97% | Validation: 80.00%
# Time elapsed: 29.96 min
# Learning rate: [0.0005]
# Epoch: 012/040 | Batch 0000/0134 | Loss: 0.6116
# Epoch: 012/040 | Batch 0100/0134 | Loss: 0.5184
# Epoch: 012/040 | Train: 79.53% | Validation: 80.00%
# Time elapsed: 32.68 min
# Learning rate: [0.0005]
# Epoch: 013/040 | Batch 0000/0134 | Loss: 0.5494
# Epoch: 013/040 | Batch 0100/0134 | Loss: 0.6294
# Epoch: 013/040 | Train: 80.59% | Validation: 81.12%
# Time elapsed: 35.38 min
# Learning rate: [0.0005]
# Epoch: 014/040 | Batch 0000/0134 | Loss: 0.6998
# Epoch: 014/040 | Batch 0100/0134 | Loss: 0.5152
# Epoch: 014/040 | Train: 80.96% | Validation: 81.03%
# Time elapsed: 38.10 min
# Learning rate: [0.0005]
# Epoch: 015/040 | Batch 0000/0134 | Loss: 0.5423
# Epoch: 015/040 | Batch 0100/0134 | Loss: 0.6184
# Epoch: 015/040 | Train: 79.99% | Validation: 80.84%
# Time elapsed: 40.80 min
# Learning rate: [0.0005]
# Epoch: 016/040 | Batch 0000/0134 | Loss: 0.5161
# Epoch: 016/040 | Batch 0100/0134 | Loss: 0.6009
# Epoch: 016/040 | Train: 81.29% | Validation: 81.31%
# Time elapsed: 43.51 min
# Learning rate: [0.0005]
# Epoch: 017/040 | Batch 0000/0134 | Loss: 0.6456
# Epoch: 017/040 | Batch 0100/0134 | Loss: 0.6532
# Epoch: 017/040 | Train: 81.34% | Validation: 80.75%
# Time elapsed: 46.27 min
# Learning rate: [0.0005]
# Epoch: 018/040 | Batch 0000/0134 | Loss: 0.6594
# Epoch: 018/040 | Batch 0100/0134 | Loss: 0.5886
# Epoch: 018/040 | Train: 80.57% | Validation: 80.84%
# Time elapsed: 48.99 min
# Learning rate: [0.0005]
# Epoch: 019/040 | Batch 0000/0134 | Loss: 0.4523
# Epoch: 019/040 | Batch 0100/0134 | Loss: 0.6514
# Epoch: 019/040 | Train: 81.21% | Validation: 80.84%
# Time elapsed: 51.68 min
# Learning rate: [0.0005]
# Epoch: 020/040 | Batch 0000/0134 | Loss: 0.5508
# Epoch: 020/040 | Batch 0100/0134 | Loss: 0.5194
# Epoch: 020/040 | Train: 81.56% | Validation: 81.21%
# Time elapsed: 54.40 min
# Learning rate: [0.00025]
# Epoch: 021/040 | Batch 0000/0134 | Loss: 0.6025
# Epoch: 021/040 | Batch 0100/0134 | Loss: 0.5137
# Epoch: 021/040 | Train: 81.80% | Validation: 81.40%
# Time elapsed: 57.11 min
# Learning rate: [0.00025]
# Epoch: 022/040 | Batch 0000/0134 | Loss: 0.5183
# Epoch: 022/040 | Batch 0100/0134 | Loss: 0.5261
# Epoch: 022/040 | Train: 82.23% | Validation: 81.96%
# Time elapsed: 59.88 min
# Learning rate: [0.00025]
# Epoch: 023/040 | Batch 0000/0134 | Loss: 0.5824
# Epoch: 023/040 | Batch 0100/0134 | Loss: 0.5094
# Epoch: 023/040 | Train: 82.35% | Validation: 81.87%
# Time elapsed: 62.61 min
# Learning rate: [0.00025]
# Epoch: 024/040 | Batch 0000/0134 | Loss: 0.4913
# Epoch: 024/040 | Batch 0100/0134 | Loss: 0.6606
# Epoch: 024/040 | Train: 82.13% | Validation: 81.78%
# Time elapsed: 65.35 min
# Learning rate: [0.00025]
# Epoch: 025/040 | Batch 0000/0134 | Loss: 0.5799
# Epoch: 025/040 | Batch 0100/0134 | Loss: 0.7164
# Epoch: 025/040 | Train: 81.98% | Validation: 81.40%
# Time elapsed: 68.13 min
# Learning rate: [0.00025]
# Epoch: 026/040 | Batch 0000/0134 | Loss: 0.5703
# Epoch: 026/040 | Batch 0100/0134 | Loss: 0.5729
# Epoch: 026/040 | Train: 82.59% | Validation: 81.78%
# Time elapsed: 70.86 min
# Learning rate: [0.00025]
# Epoch: 027/040 | Batch 0000/0134 | Loss: 0.3663
# Epoch: 027/040 | Batch 0100/0134 | Loss: 0.6317
# Epoch: 027/040 | Train: 82.56% | Validation: 81.87%
# Time elapsed: 73.57 min
# Learning rate: [0.00025]
# Epoch: 028/040 | Batch 0000/0134 | Loss: 0.5090
# Epoch: 028/040 | Batch 0100/0134 | Loss: 0.5000
# Epoch: 028/040 | Train: 82.57% | Validation: 82.24%
# Time elapsed: 76.27 min
# Learning rate: [0.00025]
# Epoch: 029/040 | Batch 0000/0134 | Loss: 0.5094
# Epoch: 029/040 | Batch 0100/0134 | Loss: 0.6771
# Epoch: 029/040 | Train: 82.64% | Validation: 82.24%
# Time elapsed: 78.97 min
# Learning rate: [0.00025]
# Epoch: 030/040 | Batch 0000/0134 | Loss: 0.4644
# Epoch: 030/040 | Batch 0100/0134 | Loss: 0.6158
# Epoch: 030/040 | Train: 82.80% | Validation: 82.71%
# Time elapsed: 81.68 min
# Learning rate: [0.000125]
# Epoch: 031/040 | Batch 0000/0134 | Loss: 0.5624
# Epoch: 031/040 | Batch 0100/0134 | Loss: 0.5132
# Epoch: 031/040 | Train: 82.92% | Validation: 82.71%
# Time elapsed: 84.38 min
# Learning rate: [0.000125]
# Epoch: 032/040 | Batch 0000/0134 | Loss: 0.5053
# Epoch: 032/040 | Batch 0100/0134 | Loss: 0.4239
# Epoch: 032/040 | Train: 82.90% | Validation: 82.52%
# Time elapsed: 87.09 min
# Learning rate: [0.000125]
# Epoch: 033/040 | Batch 0000/0134 | Loss: 0.5669
# Epoch: 033/040 | Batch 0100/0134 | Loss: 0.6355
# Epoch: 033/040 | Train: 83.09% | Validation: 82.06%
# Time elapsed: 89.80 min
# Learning rate: [0.000125]
# Epoch: 034/040 | Batch 0000/0134 | Loss: 0.4372
# Epoch: 034/040 | Batch 0100/0134 | Loss: 0.3806
# Epoch: 034/040 | Train: 83.01% | Validation: 82.34%
# Time elapsed: 92.51 min
# Learning rate: [0.000125]
# Epoch: 035/040 | Batch 0000/0134 | Loss: 0.5233
# Epoch: 035/040 | Batch 0100/0134 | Loss: 0.5378
# Epoch: 035/040 | Train: 82.88% | Validation: 82.43%
# Time elapsed: 95.22 min
# Learning rate: [0.000125]
# Epoch: 036/040 | Batch 0000/0134 | Loss: 0.6820
# Epoch: 036/040 | Batch 0100/0134 | Loss: 0.5921
# Epoch: 036/040 | Train: 83.32% | Validation: 82.15%
# Time elapsed: 97.96 min
# Learning rate: [0.000125]
# Epoch: 037/040 | Batch 0000/0134 | Loss: 0.3850
# Epoch: 037/040 | Batch 0100/0134 | Loss: 0.4513
# Epoch: 037/040 | Train: 83.07% | Validation: 82.43%
# Time elapsed: 100.67 min
# Early stopping
# Total Training Time: 100.67 min
# Test accuracy 79.37%

# %%
model.cpu()
unnormalizer = UnNormalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
class_dict = {0: 'CBB',
              1: 'CBSD',
              2: 'CGM',
              3: 'CMD',
              4: 'Healthy'}

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %%
mat = compute_confusion_matrix(model=model, data_loader=test_loader, device=torch.device('cpu'))
plot_confusion_matrix(mat, class_names=class_dict.values())
plt.show()

# %%
torch.save(model.state_dict(), 'AlexNet2.mdl')
